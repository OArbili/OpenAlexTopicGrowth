# %%
import requests
import time
from collections import defaultdict
import json
from datetime import datetime
import os

class USAArticlesCategorizer:
    def __init__(self, email):
        self.base_url = "https://api.openalex.org/works"
        self.headers = {
            "User-Agent": f"ArticlesCategorizer/{email}",
            "Accept": "application/json"
        }
        self.output_dir = "openalex_topics_results"
        os.makedirs(self.output_dir, exist_ok=True)
        
    def fetch_articles(self, year=2024, page_size=200):
        """
        Fetch articles from USA institutions for a specific year with at least 5 citations
        """
        articles = []
        cursor = "*"
        
        while True:
            params = {
                "filter": (
                    f"publication_year:{year},"
                    "institutions.country_code:US,"
                    "type:article,"
                    "cited_by_count:>5"  # Filter for articles with more than 5 citations
                ),
                "per_page": page_size,
                "cursor": cursor,
                "select": "id,title,topics,authorships,institutions_distinct_count,cited_by_count"
            }
            
            try:
                response = requests.get(self.base_url, params=params, headers=self.headers)
                print(f"Request URL: {response.url}")
                
                if response.status_code != 200:
                    print(f"Error fetching data: {response.status_code}")
                    print(f"Error details: {response.text}")
                    break
                    
                data = response.json()
                
                # Check if we got any results
                results = data.get("results", [])
                if results:
                    articles.extend(results)
                    
                    # Print meta information for debugging
                    meta = data.get("meta", {})
                    print(f"Page results: {len(results)}")
                    print(f"Total results from API: {meta.get('count', 0)}")
                    print(f"Current page: {meta.get('page', 0)}")
                    
                    # Save raw data periodically
                    if len(articles) % 1000 == 0:
                        self.save_raw_data(articles, year)
                        print(f"Fetched {len(articles)} highly-cited articles so far...")
                
                cursor = data.get("meta", {}).get("next_cursor")
                if not cursor:
                    break
                    
                time.sleep(0.1)  # Rate limiting
                
            except Exception as e:
                print(f"Error during fetch: {str(e)}")
                break
        
        # Save final raw data
        self.save_raw_data(articles, year)
        print(f"Final count: {len(articles)} highly-cited articles fetched")
        return articles
    
    def save_raw_data(self, articles, year):
        """Save raw article data to JSON file"""
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = os.path.join(self.output_dir, f"highly_cited_articles_{year}_{timestamp}.json")
        with open(filename, 'w', encoding='utf-8') as f:
            json.dump(articles, f, indent=2)
        print(f"Saved raw data to {filename}")
    
    def categorize_articles(self, articles):
        """
        Categorize articles by their top-level research topics
        """
        categories = defaultdict(list)
        topic_mapping = {}  # Store topic ID to name mapping
        
        for article in articles:
            topics = article.get("topics", [])
            if not topics:
                categories["Uncategorized"].append({
                    "article": article,
                    "topic_id": None,
                    "citations": article.get("cited_by_count", 0)
                })
                continue
                
            topics.sort(key=lambda x: x.get("score", 0), reverse=True)
            top_topic = topics[0]
            topic_id = top_topic.get("id")
            topic_name = top_topic.get("display_name", "Uncategorized")
            
            # Store topic mapping
            topic_mapping[topic_id] = topic_name
            
            categories[topic_name].append({
                "article": article,
                "topic_id": topic_id,
                "citations": article.get("cited_by_count", 0)
            })
        
        return categories, topic_mapping
    
    def generate_report(self, categories, topic_mapping):
        """
        Generate a summary report of the categorized highly-cited articles
        """
        total_articles = sum(len(articles) for articles in categories.values())
        
        report = {
            "total_highly_cited_articles": total_articles,
            "categories": {},
            "top_institutions": defaultdict(int),
            "topic_mapping": topic_mapping
        }
        
        for category, articles in categories.items():
            topic_id = articles[0]["topic_id"] if articles and articles[0]["topic_id"] else "uncategorized"
            
            category_stats = {
                "topic_id": topic_id,
                "article_count": len(articles),
                "percentage": (len(articles) / total_articles) * 100,
                "average_citations": sum(art["citations"] for art in articles) / len(articles),
                "sample_titles": [art["article"]["title"] for art in articles[:3]]
            }
            
            for article_data in articles:
                article = article_data["article"]
                for authorship in article.get("authorships", []):
                    for institution in authorship.get("institutions", []):
                        if institution.get("country_code") == "US":
                            report["top_institutions"][institution.get("display_name", "Unknown")] += 1
            
            report["categories"][category] = category_stats
        
        report["top_institutions"] = dict(
            sorted(report["top_institutions"].items(), 
                  key=lambda x: x[1], 
                  reverse=True)[:10]
        )
        
        return report
    
    def save_report(self, report, year):
        """Save report to JSON format"""
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        json_filename = os.path.join(self.output_dir, f"highly_cited_report_{year}_{timestamp}.json")
        with open(json_filename, 'w', encoding='utf-8') as f:
            json.dump(report, f, indent=2)
        print(f"Saved report to {json_filename}")

# %%
# Imports
import sys
import logging
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# from article_analyzer import USAArticlesCategorizer

# Setup logging for notebook
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    stream=sys.stdout
)
logger = logging.getLogger(__name__)

# Configuration
EMAIL = "ofir.arbili@gmail.com"  # Replace with your email
YEAR = 2024
PAGE_SIZE = 50  # Start with smaller page size for testing

# Initialize the categorizer
logger.info(f"Initializing categorizer with email: {EMAIL}")
categorizer = USAArticlesCategorizer(EMAIL)

# Fetch articles
logger.info(f"Fetching articles for year {YEAR}")
articles = categorizer.fetch_articles(year=YEAR, page_size=PAGE_SIZE)

if articles:
    logger.info(f"Successfully fetched {len(articles)} articles")
    
    # Categorize articles
    logger.info("Categorizing articles by topics...")
    categories, topic_mapping = categorizer.categorize_articles(articles)
    
    # Generate report
    logger.info("Generating report...")
    report = categorizer.generate_report(categories, topic_mapping)
    
    # Save report
    logger.info("Saving report...")
    categorizer.save_report(report, YEAR)
    
    # Analysis and Visualization
    
    # 1. Create DataFrame for topics
    topics_df = pd.DataFrame([
        {
            'topic': topic,
            'topic_id': stats['topic_id'],
            'count': stats['article_count'],
            'percentage': stats['percentage']
        }
        for topic, stats in report['categories'].items()
    ])
    
    # Sort by count
    topics_df = topics_df.sort_values('count', ascending=False)
    
    # 2. Create DataFrame for institutions
    institutions_df = pd.DataFrame([
        {'institution': inst, 'count': count}
        for inst, count in report['top_institutions'].items()
    ]).sort_values('count', ascending=False)
    
    # Plotting
    plt.style.use('seaborn')
    
    # 1. Top Topics Bar Plot
    plt.figure(figsize=(15, 8))
    sns.barplot(data=topics_df.head(10), x='count', y='topic')
    plt.title(f'Top 10 Topics in US Research Publications ({YEAR})')
    plt.xlabel('Number of Articles')
    plt.ylabel('Topic')
    plt.tight_layout()
    plt.show()
    
    # 2. Topics Pie Chart
    plt.figure(figsize=(12, 12))
    plt.pie(topics_df.head(10)['percentage'], 
            labels=topics_df.head(10)['topic'],
            autopct='%1.1f%%')
    plt.title(f'Distribution of Top 10 Topics ({YEAR})')
    plt.axis('equal')
    plt.show()
    
    # 3. Top Institutions Bar Plot
    plt.figure(figsize=(15, 8))
    sns.barplot(data=institutions_df.head(10), x='count', y='institution')
    plt.title(f'Top 10 Contributing US Institutions ({YEAR})')
    plt.xlabel('Number of Articles')
    plt.ylabel('Institution')
    plt.tight_layout()
    plt.show()
    
    # Print Summary Statistics
    print("\nSummary Statistics:")
    print(f"Total Articles: {report['total_articles']}")
    print(f"Number of Topics: {len(topics_df)}")
    print(f"Number of Contributing Institutions: {len(institutions_df)}")
    
    print("\nTop 5 Topics:")
    for _, row in topics_df.head().iterrows():
        print(f"{row['topic']} ({row['topic_id']}): {row['count']} articles ({row['percentage']:.1f}%)")
    
    print("\nTop 5 Institutions:")
    for _, row in institutions_df.head().iterrows():
        print(f"{row['institution']}: {row['count']} articles")
    
    # Save processed data
    topics_df.to_csv(f'topics_analysis_{YEAR}.csv', index=False)
    institutions_df.to_csv(f'institutions_analysis_{YEAR}.csv', index=False)
    
    logger.info("Analysis complete!")
else:
    logger.error("No articles were fetched.")
# Out:
# 2025-02-21 22:27:28,587 - INFO - Initializing categorizer with email: ofir.arbili@gmail.com
# 2025-02-21 22:27:28,588 - INFO - Fetching articles for year 2024
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=%2A&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTY0LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTA5Njc3MjEnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTEzLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTE1NjUxOTUnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgOTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjM3NjI5NCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgODMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjE5OTM3MCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgNzMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQwMjczMzU4NSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgNjUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjU1MzU1NyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgNTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDcwNzYzOCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgNTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NTQ2OTQ3MiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgNTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjI0MjMxNiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgNTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjIzMjU5NCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgNDgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjI5Njk5MyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgNDYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTE2NzAzMyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgNDUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5OTg1NDc5NyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgNDMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjgwMjQ3NyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgNDIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQwMDcyOTUxMyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgNDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTE2OTAzMyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMzksICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjY5OTc3NCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMzgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NDU4MDk3OCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMzcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NjIzMDI2NSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Saved raw data to openalex_topics_results/highly_cited_articles_2024_20250221_222754.json
# Fetched 1000 highly-cited articles so far...
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMzYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NTA3MTMxNyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMzUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MzE2MDIwNCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMzQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTg4MjgwNSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMzMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDgzNzY0MSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMzMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NjkxOTAyNyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMzIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTQ1MDcxOCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMzEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjQ2MTMwNjEnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMzEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjAyODQyNyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMzEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5OTk5NjU4OSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMzAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjkwNjY0NCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjksICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDU5MDkwMCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjksICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjM4MTE4MiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDU3Nzg2OSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjAyODQyNiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5OTM3NDExNiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTMwOTQxMCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5Mzg1ODM1MSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDU5OTQ2MSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTY5NDAwNiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NDk5NzU5MSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Saved raw data to openalex_topics_results/highly_cited_articles_2024_20250221_222818.json
# Fetched 2000 highly-cited articles so far...
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDc0OTcxNyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjQ2MTc5MiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5Njc3OTQ2MyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDc1MzY3NSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTk4MzcwNyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NDU2NzI1NyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQwMTk1NDM5MCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTExMjg2OSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5Mjc2MTYzMSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NjkxMjYzNSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDU4NTUyNiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTI2MjY4MSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5Mjc5ODY1NSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NTA3MDgyNSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQwMDkzNzU1NSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDkwNzQ3NSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTY1NDY0NiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjgwMTgzNiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NTAwMzAwMCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQwMTE3MTkzNyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Saved raw data to openalex_topics_results/highly_cited_articles_2024_20250221_222842.json
# Fetched 3000 highly-cited articles so far...
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDcwOTEwMCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTMxMDM3NCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjA0MTMzNCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MzAyNTIzMyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NjIyODIwMyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5OTU2NzQ2NSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDUzNTg0NCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDk0NzI2NiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTYxODE5NyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjQ1MTQ2OSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MzM0MzkxNyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5Njc2MDQ4MSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQwMDM1NzE3NSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDU2NTEyNyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDk4ODc2OSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTM2NTEyMiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTkyNDg1MyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjY0MzE3MSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MzM3NTM4MyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NTQ2NzU2MSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Saved raw data to openalex_topics_results/highly_cited_articles_2024_20250221_222907.json
# Fetched 4000 highly-cited articles so far...
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5OTg5Mzk0OSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzEyMjAxNjU3NSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDg4NDY3OSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTMyMzM4NyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTc1NzQ2NyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjIxOTYxNCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5Mjc2NjAxMCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MzM5NzE1MiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NTk1OTkwMCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5OTMwMDQzOCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQwMTkzNTUxOSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDYxNTUxNCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTAyNzQ3MiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTM2MTA3NCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTg0MjcxOSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjM4NDYwNCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjkyNjgyNiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5Mzk0NTg3NCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NjU0MDA5NSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5OTExNzA2NiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Saved raw data to openalex_topics_results/highly_cited_articles_2024_20250221_222933.json
# Fetched 5000 highly-cited articles so far...
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQwMDY1MzAxMiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQwNDk5MjI5MCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDY2MjgwMiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTAyNzQ0OSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTM0Nzg4MSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTY0NDA4NiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjAzNDA0OCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjM4MzUxNiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5Mjg5NDEwNCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MzMwNzUwNyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NDkzMzQyMCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NjkwNjkzMyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5OTU2NjE0MiddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDQwMTQzNDAxNCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzIxNjg5NTE3MyddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDY3MDI2NSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDkxMjg1MCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTEwODIxMCddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=IlsxMDAuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MTM4Mzc1NSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# ...
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTI3NjE3OTEnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTI4NzA4MTEnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTI5NTMwNTAnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTMwOTg1MjInXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTMyMDM4NDInXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTMzMTEzNzQnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTM1MTU5NTYnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTM5NzM3NTcnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTQ1OTQ0MzYnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTQ2ODY0MTQnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTQ3ODcyOTUnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTQ5NjQ3NDYnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTY0OTY1MDUnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTY2Njk3ODUnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTY3MzYwMDQnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTY4MTI5MjInXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Saved raw data to openalex_topics_results/highly_cited_articles_2024_20250221_224025.json
# Fetched 27000 highly-cited articles so far...
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTY4NzE5MjInXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTY5MjU0MzcnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTgxNDczNTgnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTkwODc4NTcnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTkyNzk1NDAnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTk0NTI1MjInXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTk2MTI3NjEnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTk4ODcxODInXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDAyMzk2NDMnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDA4NTMzMjYnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDEwMjQwMTgnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDEzNTA2OTgnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDE2NDg2MDcnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDIzNDY5NjYnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDI3MDA1MjEnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDMxNTE1ODgnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 50
# Total results from API: 27814
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDQ2MTMxMDcnXSI%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Page results: 13
# Total results from API: 27815
# Current page: None
# Request URL: https://api.openalex.org/works?filter=publication_year%3A2024%2Cinstitutions.country_code%3AUS%2Ctype%3Aarticle%2Ccited_by_count%3A%3E5&per_page=50&cursor=Ils5OC4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzYxODkzODE4OSddIg%3D%3D&select=id%2Ctitle%2Ctopics%2Cauthorships%2Cinstitutions_distinct_count%2Ccited_by_count
# Saved raw data to openalex_topics_results/highly_cited_articles_2024_20250221_224056.json
# Final count: 27813 highly-cited articles fetched
# 2025-02-21 22:41:06,751 - INFO - Successfully fetched 27813 articles
# 2025-02-21 22:41:06,752 - INFO - Categorizing articles by topics...
# 2025-02-21 22:41:06,818 - INFO - Generating report...
# 2025-02-21 22:41:07,058 - INFO - Saving report...
# Saved report to openalex_topics_results/highly_cited_report_2024_20250221_224107.json
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.conda/envs/gnn2025/lib/python3.13/site-packages/matplotlib/style/core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File ~/.conda/envs/gnn2025/lib/python3.13/site-packages/matplotlib/__init__.py:903, in _rc_params_in_file(fname, transform, fail_on_error)
#     902 rc_temp = {}
# --> 903 with _open_file_or_url(fname) as fd:
#     904     try:
#
# File ~/.conda/envs/gnn2025/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#
# File ~/.conda/envs/gnn2025/lib/python3.13/site-packages/matplotlib/__init__.py:880, in _open_file_or_url(fname)
#     879 fname = os.path.expanduser(fname)
# --> 880 with open(fname, encoding='utf-8') as f:
#     881     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seaborn'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 69
#      63 institutions_df = pd.DataFrame([
#      64     {'institution': inst, 'count': count}
#      65     for inst, count in report['top_institutions'].items()
#      66 ]).sort_values('count', ascending=False)
#      68 # Plotting
# ---> 69 plt.style.use('seaborn')
#      71 # 1. Top Topics Bar Plot
#      72 plt.figure(figsize=(15, 8))
#
# File ~/.conda/envs/gnn2025/lib/python3.13/site-packages/matplotlib/style/core.py:131, in use(style)
#     129         style = _rc_params_in_file(style)
#     130     except OSError as err:
# --> 131         raise OSError(
#     132             f"{style!r} is not a valid package style, path of style "
#     133             f"file, URL of style file, or library style name (library "
#     134             f"styles are listed in `style.available`)") from err
#     135 filtered = {}
#     136 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'seaborn' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)

# %%
# # Imports
# import sys
# import logging
# from datetime import datetime
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# # from article_analyzer import USAArticlesCategorizer

# # Setup logging for notebook
# logging.basicConfig(
#     level=logging.INFO,
#     format='%(asctime)s - %(levelname)s - %(message)s',
#     stream=sys.stdout
# )
# logger = logging.getLogger(__name__)

# # Configuration
# EMAIL = "ofir.arbili@gmail.com"  # Replace with your email
# YEAR = 2024
# PAGE_SIZE = 50  # Start with smaller page size for testing

# # Initialize the categorizer
# logger.info(f"Initializing categorizer with email: {EMAIL}")
# categorizer = USAArticlesCategorizer(EMAIL)

# # Fetch articles
# logger.info(f"Fetching articles for year {YEAR}")
# articles = categorizer.fetch_articles(year=YEAR, page_size=PAGE_SIZE)

# if articles:
#     logger.info(f"Successfully fetched {len(articles)} articles")
    
#     # Categorize articles
#     logger.info("Categorizing articles by topics...")
#     categories, topic_mapping = categorizer.categorize_articles(articles)
    
#     # Generate report
#     logger.info("Generating report...")
#     report = categorizer.generate_report(categories, topic_mapping)
    
#     # Save report
#     logger.info("Saving report...")
#     categorizer.save_report(report, YEAR)
    
#     # Analysis and Visualization
    
#     # 1. Create DataFrame for topics
#     topics_df = pd.DataFrame([
#         {
#             'topic': topic,
#             'topic_id': stats['topic_id'],
#             'count': stats['article_count'],
#             'percentage': stats['percentage']
#         }
#         for topic, stats in report['categories'].items()
#     ])
    
#     # Sort by count
#     topics_df = topics_df.sort_values('count', ascending=False)
    
#     # 2. Create DataFrame for institutions
#     institutions_df = pd.DataFrame([
#         {'institution': inst, 'count': count}
#         for inst, count in report['top_institutions'].items()
#     ]).sort_values('count', ascending=False)
    
#     # Plotting
#     plt.style.use('seaborn')
    
#     # 1. Top Topics Bar Plot
#     plt.figure(figsize=(15, 8))
#     sns.barplot(data=topics_df.head(10), x='count', y='topic')
#     plt.title(f'Top 10 Topics in US Research Publications ({YEAR})')
#     plt.xlabel('Number of Articles')
#     plt.ylabel('Topic')
#     plt.tight_layout()
#     plt.show()
    
#     # 2. Topics Pie Chart
#     plt.figure(figsize=(12, 12))
#     plt.pie(topics_df.head(10)['percentage'], 
#             labels=topics_df.head(10)['topic'],
#             autopct='%1.1f%%')
#     plt.title(f'Distribution of Top 10 Topics ({YEAR})')
#     plt.axis('equal')
#     plt.show()
    
#     # 3. Top Institutions Bar Plot
#     plt.figure(figsize=(15, 8))
#     sns.barplot(data=institutions_df.head(10), x='count', y='institution')
#     plt.title(f'Top 10 Contributing US Institutions ({YEAR})')
#     plt.xlabel('Number of Articles')
#     plt.ylabel('Institution')
#     plt.tight_layout()
#     plt.show()
    
#     # Print Summary Statistics
#     print("\nSummary Statistics:")
#     print(f"Total Articles: {report['total_articles']}")
#     print(f"Number of Topics: {len(topics_df)}")
#     print(f"Number of Contributing Institutions: {len(institutions_df)}")
    
#     print("\nTop 5 Topics:")
#     for _, row in topics_df.head().iterrows():
#         print(f"{row['topic']} ({row['topic_id']}): {row['count']} articles ({row['percentage']:.1f}%)")
    
#     print("\nTop 5 Institutions:")
#     for _, row in institutions_df.head().iterrows():
#         print(f"{row['institution']}: {row['count']} articles")
    
#     # Save processed data
#     topics_df.to_csv(f'topics_analysis_{YEAR}.csv', index=False)
#     institutions_df.to_csv(f'institutions_analysis_{YEAR}.csv', index=False)
    
#     logger.info("Analysis complete!")
# else:
#     logger.error("No articles were fetched.")

# %%
# !pwd
# Out:
# /sise/liorrk-group/OrDanOfir/Miki
