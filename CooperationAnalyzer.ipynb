# %%
import json
import pandas as pd
import numpy as np
from collections import defaultdict
from pathlib import Path
import glob
import os

class CrossFieldAnalyzer:
    def __init__(self, data_folder="openalex_topics_results"):
        self.data_folder = Path(data_folder)
        
    def load_all_data(self):
        """
        Load and combine all available JSON files
        """
        pattern = os.path.join(self.data_folder, "highly_cited_articles_*.json")
        files = glob.glob(pattern)
        
        if not files:
            raise FileNotFoundError("No article files found")
        
        all_papers = []
        for file_path in files:
            print(f"Loading data from {os.path.basename(file_path)}")
            with open(file_path, 'r', encoding='utf-8') as f:
                papers = json.load(f)
                all_papers.extend(papers)
        
        print(f"Loaded total of {len(all_papers)} papers from {len(files)} files")
        return all_papers
        
    def analyze_cooperations(self, papers, min_score=0.3):
        """
        Analyze cross-field cooperation patterns between topics
        """
        topic_cooperations = defaultdict(lambda: defaultdict(int))
        field_cooperations = defaultdict(lambda: defaultdict(int))
        topic_counts = defaultdict(int)
        field_counts = defaultdict(int)
        field_to_topics = defaultdict(set)
        topic_to_field = {}
        paper_counts = defaultdict(lambda: defaultdict(int))
        
        for paper in papers:
            topics = paper.get("topics", [])
            relevant_topics = [t for t in topics if t.get("score", 0) >= min_score]
            
            # Update individual counts and mappings
            for topic in relevant_topics:
                topic_name = topic["display_name"]
                field_name = topic["field"]["display_name"]
                topic_counts[topic_name] += 1
                field_counts[field_name] += 1
                field_to_topics[field_name].add(topic_name)
                topic_to_field[topic_name] = field_name
                
            # Analyze cross-field topic cooperations
            for i, topic1 in enumerate(relevant_topics[:-1]):
                for topic2 in relevant_topics[i+1:]:
                    field1 = topic1["field"]["display_name"]
                    field2 = topic2["field"]["display_name"]
                    
                    # Skip if topics are from the same field
                    if field1 == field2:
                        continue
                        
                    t1_name = topic1["display_name"]
                    t2_name = topic2["display_name"]
                    
                    # Sort names for consistency
                    t1_name, t2_name = sorted([t1_name, t2_name])
                    field1, field2 = sorted([field1, field2])
                    
                    # Weight by topic scores
                    weight = topic1["score"] * topic2["score"]
                    
                    # Update cooperations
                    topic_cooperations[t1_name][t2_name] += weight
                    field_cooperations[field1][field2] += weight
                    paper_counts[t1_name][t2_name] += 1
        
        return {
            'topic_cooperations': topic_cooperations,
            'field_cooperations': field_cooperations,
            'topic_counts': topic_counts,
            'field_counts': field_counts,
            'field_to_topics': field_to_topics,
            'topic_to_field': topic_to_field,
            'paper_counts': paper_counts
        }
    
    def calculate_metrics(self, analysis_results):
        """
        Calculate cooperation metrics
        """
        topic_metrics = []
        field_metrics = []
        
        # Calculate topic-level metrics
        topic_coops = analysis_results['topic_cooperations']
        topic_counts = analysis_results['topic_counts']
        topic_to_field = analysis_results['topic_to_field']
        paper_counts = analysis_results['paper_counts']
        
        for topic1 in topic_coops:
            field1 = topic_to_field[topic1]
            for topic2, weight in topic_coops[topic1].items():
                field2 = topic_to_field[topic2]
                
                if field1 != field2:
                    total_possible = min(topic_counts[topic1], topic_counts[topic2])
                    papers = paper_counts[topic1][topic2]
                    
                    metric = {
                        'topic1': topic1,
                        'topic2': topic2,
                        'field1': field1,
                        'field2': field2,
                        'weight': weight,
                        'paper_count': papers,
                        'normalized_weight': weight / total_possible if total_possible > 0 else 0,
                        'topic1_count': topic_counts[topic1],
                        'topic2_count': topic_counts[topic2]
                    }
                    topic_metrics.append(metric)
        
        # Calculate field-level metrics
        field_coops = analysis_results['field_cooperations']
        field_counts = analysis_results['field_counts']
        
        for field1 in field_coops:
            for field2, weight in field_coops[field1].items():
                if field1 != field2:
                    total_possible = min(field_counts[field1], field_counts[field2])
                    
                    metric = {
                        'field1': field1,
                        'field2': field2,
                        'weight': weight,
                        'normalized_weight': weight / total_possible if total_possible > 0 else 0,
                        'field1_count': field_counts[field1],
                        'field2_count': field_counts[field2]
                    }
                    field_metrics.append(metric)
        
        # Sort by normalized weight
        topic_metrics.sort(key=lambda x: x['normalized_weight'], reverse=True)
        field_metrics.sort(key=lambda x: x['normalized_weight'], reverse=True)
        
        return topic_metrics, field_metrics
    
    def identify_clusters(self, metrics, threshold=0.3, min_cluster_size=3):
        """
        Identify clusters of closely cooperating topics or fields
        """
        items = set()
        item_to_field = {}
        
        # Build item sets and field mappings
        for m in metrics:
            if 'topic1' in m:
                items.add(m['topic1'])
                items.add(m['topic2'])
                item_to_field[m['topic1']] = m['field1']
                item_to_field[m['topic2']] = m['field2']
            else:
                # For field metrics, ensure fields are different
                if m['field1'] != m['field2']:
                    items.add(m['field1'])
                    items.add(m['field2'])
            
        item_list = sorted(list(items))
        item_idx = {item: i for i, item in enumerate(item_list)}
        
        # Create adjacency matrix
        n = len(item_list)
        adj_matrix = np.zeros((n, n))
        
        for m in metrics:
            if m['normalized_weight'] >= threshold:
                if 'topic1' in m:
                    # For topics, check they're from different fields
                    if item_to_field[m['topic1']] != item_to_field[m['topic2']]:
                        i, j = item_idx[m['topic1']], item_idx[m['topic2']]
                        adj_matrix[i, j] = m['normalized_weight']
                        adj_matrix[j, i] = m['normalized_weight']
                else:
                    # For fields, ensure they're different
                    if m['field1'] != m['field2']:
                        i, j = item_idx[m['field1']], item_idx[m['field2']]
                        adj_matrix[i, j] = m['normalized_weight']
                        adj_matrix[j, i] = m['normalized_weight']
        
        # Find clusters
        clusters = []
        visited = set()
        
        for i in range(n):
            if i not in visited:
                cluster = []
                stack = [i]
                cluster_fields = set()  # Track fields in cluster
                
                while stack:
                    node = stack.pop()
                    if node not in visited:
                        visited.add(node)
                        item = item_list[node]
                        
                        # For topics, check field diversity
                        if 'topic1' in metrics[0]:  # Check if we're dealing with topics
                            field = item_to_field[item]
                            if field not in cluster_fields or not cluster_fields:
                                cluster.append(item)
                                cluster_fields.add(field)
                        else:  # For fields, just add if different
                            cluster.append(item)
                        
                        # Add neighbors
                        for j in range(n):
                            if adj_matrix[node, j] >= threshold and j not in visited:
                                next_item = item_list[j]
                                # Check if adding would maintain field diversity
                                if 'topic1' in metrics[0]:
                                    next_field = item_to_field[next_item]
                                    if next_field not in cluster_fields:
                                        stack.append(j)
                                else:
                                    if next_item not in cluster:
                                        stack.append(j)
                
                if len(cluster) >= min_cluster_size:
                    clusters.append(cluster)
        
        # Sort clusters by size
        clusters.sort(key=len, reverse=True)
        return clusters
    
    def generate_report(self, topic_metrics, field_metrics, topic_clusters, field_clusters):
        """
        Generate a comprehensive report of the cooperation analysis
        """
        report = {
            'topic_analysis': {
                'top_cooperations': topic_metrics[:20],
                'clusters': topic_clusters,
                'summary_stats': {
                    'total_pairs': len(topic_metrics),
                    'avg_weight': np.mean([m['normalized_weight'] for m in topic_metrics]),
                    'avg_papers': np.mean([m['paper_count'] for m in topic_metrics])
                }
            },
            'field_analysis': {
                'top_cooperations': field_metrics[:20],
                'clusters': field_clusters,
                'summary_stats': {
                    'total_pairs': len(field_metrics),
                    'avg_weight': np.mean([m['normalized_weight'] for m in field_metrics])
                }
            }
        }
        return report

def print_report(report):
    """
    Print a formatted version of the cooperation report
    """
    print("\n=== Cross-Field Cooperation Analysis Report ===\n")
    
    print("Top Topic Cooperations:")
    for i, coop in enumerate(report['topic_analysis']['top_cooperations'][:10], 1):
        print(f"\n{i}. {coop['topic1']} ({coop['field1']}) × {coop['topic2']} ({coop['field2']})")
        print(f"   Papers: {coop['paper_count']}")
        print(f"   Normalized Weight: {coop['normalized_weight']:.3f}")
    
    print("\nTopic Clusters:")
    for i, cluster in enumerate(report['topic_analysis']['clusters'], 1):
        print(f"\nCluster {i}:")
        print("  " + ", ".join(cluster))
    
    print("\nField Cooperations:")
    for i, coop in enumerate(report['field_analysis']['top_cooperations'][:10], 1):
        print(f"\n{i}. {coop['field1']} × {coop['field2']}")
        print(f"   Normalized Weight: {coop['normalized_weight']:.3f}")
    
    print("\nField Clusters:")
    for i, cluster in enumerate(report['field_analysis']['clusters'], 1):
        print(f"\nCluster {i}:")
        print("  " + ", ".join(cluster))
    
    print("\nSummary Statistics:")
    t_stats = report['topic_analysis']['summary_stats']
    f_stats = report['field_analysis']['summary_stats']
    print(f"Total Topic Pairs: {t_stats['total_pairs']}")
    print(f"Average Topic Normalized Weight: {t_stats['avg_weight']:.3f}")
    print(f"Average Papers per Topic Pair: {t_stats['avg_papers']:.1f}")
    print(f"Total Field Pairs: {f_stats['total_pairs']}")
    print(f"Average Field Normalized Weight: {f_stats['avg_weight']:.3f}")

# Usage example
if __name__ == "__main__":
    analyzer = CrossFieldAnalyzer()
    
    # Load and analyze all data
    papers = analyzer.load_all_data()
    analysis_results = analyzer.analyze_cooperations(papers)
    topic_metrics, field_metrics = analyzer.calculate_metrics(analysis_results)
    
    # Identify clusters
    topic_clusters = analyzer.identify_clusters(topic_metrics)
    field_clusters = analyzer.identify_clusters(field_metrics)
    
    # Generate and print report
    report = analyzer.generate_report(topic_metrics, field_metrics, 
                                    topic_clusters, field_clusters)
    print_report(report)
    
    # Create visualization
    svg_content = visualize_cooperations(report)
    
    # Save visualization as SVG artifact
    with open('topic_network.svg', 'w', encoding='utf-8') as f:
        f.write(svg_content)
# Out:
# Loading data from highly_cited_articles_2024_20250221_222754.json
# Loading data from highly_cited_articles_2024_20250221_222818.json
# Loading data from highly_cited_articles_2024_20250221_222842.json
# Loading data from highly_cited_articles_2024_20250221_222907.json
# Loading data from highly_cited_articles_2024_20250221_222933.json
# Loading data from highly_cited_articles_2024_20250221_223000.json
# Loading data from highly_cited_articles_2024_20250221_223026.json
# Loading data from highly_cited_articles_2024_20250221_223052.json
# Loading data from highly_cited_articles_2024_20250221_223119.json
# Loading data from highly_cited_articles_2024_20250221_223149.json
# Loading data from highly_cited_articles_2024_20250221_223218.json
# Loading data from highly_cited_articles_2024_20250221_223247.json
# Loading data from highly_cited_articles_2024_20250221_223315.json
# Loading data from highly_cited_articles_2024_20250221_223343.json
# Loading data from highly_cited_articles_2024_20250221_223412.json
# Loading data from highly_cited_articles_2024_20250221_223441.json
# Loading data from highly_cited_articles_2024_20250221_223512.json
# Loading data from highly_cited_articles_2024_20250221_223543.json
# Loading data from highly_cited_articles_2024_20250221_223612.json
# Loading data from highly_cited_articles_2024_20250221_223643.json
# Loading data from highly_cited_articles_2024_20250221_223714.json
# Loading data from highly_cited_articles_2024_20250221_223746.json
# Loading data from highly_cited_articles_2024_20250221_223815.json
# Loading data from highly_cited_articles_2024_20250221_223847.json
# Loading data from highly_cited_articles_2024_20250221_223919.json
# Loading data from highly_cited_articles_2024_20250221_223951.json
# Loading data from highly_cited_articles_2024_20250221_224025.json
# Loading data from highly_cited_articles_2024_20250221_224056.json
# Loaded total of 405813 papers from 28 files
#
# === Cross-Field Cooperation Analysis Report ===
#
# Top Topic Cooperations:
#
# 1. Cardiovascular Conditions and Treatments (Medicine) × Mechanical Circulatory Support Devices (Engineering)
#    Papers: 12
#    Normalized Weight: 1.000
#
# 2. Photonic and Optical Devices (Engineering) × Silicon Nanostructures and Photoluminescence (Materials Science)
#    Papers: 9
#    Normalized Weight: 1.000
#
# 3. Quantum optics and atomic interactions (Physics and Astronomy) × Silicon Nanostructures and Photoluminescence (Materials Science)
#    Papers: 9
#    Normalized Weight: 0.999
#
# 4. IoT Networks and Protocols (Engineering) × Wireless Networks and Protocols (Computer Science)
#    Papers: 6
#    Normalized Weight: 0.999
#
# 5. Bone Tissue Engineering Materials (Engineering) × Thallium and Germanium Studies (Environmental Science)
#    Papers: 9
#    Normalized Weight: 0.999
#
# 6. Advanced Wireless Communication Technologies (Engineering) × Cognitive Radio Networks and Spectrum Sensing (Computer Science)
#    Papers: 5
#    Normalized Weight: 0.999
#
# 7. Advanced MIMO Systems Optimization (Engineering) × Cognitive Radio Networks and Spectrum Sensing (Computer Science)
#    Papers: 5
#    Normalized Weight: 0.999
#
# 8. Essential Oils and Antimicrobial Activity (Agricultural and Biological Sciences) × Psidium guajava Extracts and Applications (Pharmacology, Toxicology and Pharmaceutics)
#    Papers: 14
#    Normalized Weight: 0.999
#
# 9. Congenital limb and hand anomalies (Biochemistry, Genetics and Molecular Biology) × Orthopedic Surgery and Rehabilitation (Medicine)
#    Papers: 9
#    Normalized Weight: 0.999
#
# 10. Machine Learning and ELM (Computer Science) × Power Quality and Harmonics (Engineering)
#    Papers: 20
#    Normalized Weight: 0.999
#
# Topic Clusters:
#
# Cluster 1:
#   AI and Big Data Applications, Artificial Intelligence in Healthcare and Education, Team Dynamics and Performance, Social Media in Health Education, Health Literacy and Information Accessibility, Orthodontics and Dentofacial Orthopedics, Nursing Diagnosis and Documentation, Meta-analysis and systematic reviews, Academic Writing and Publishing, Medical Imaging and Analysis, Neuroethics, Human Enhancement, Biomedical Innovations, Digital Transformation in Law, AI and HR Technologies
#
# Cluster 2:
#   Advanced Chemical Physics Studies, History and advancements in chemistry, Chemistry and Chemical Engineering, University-Industry-Government Innovation Models, Sustainability in Higher Education, Engineering Education and Curriculum Development, Educational Research and Pedagogy, Cancer and biochemical research, Catalysis and Oxidation Reactions, Catalytic Processes in Materials Science, Plasma Applications and Diagnostics
#
# Cluster 3:
#   Alkaloids: synthesis and pharmacology, Traditional and Medicinal Uses of Annonaceae, Chemical synthesis and alkaloids, Psychotherapy Techniques and Applications, Neurotransmitter Receptor Influence on Behavior, Diverse academic research themes, Complementary and Alternative Medicine Studies, Therapeutic Uses of Natural Elements, Phytochemistry Medicinal Plant Applications, Pomegranate: compositions and health benefits, Endodontics and Root Canal Treatments
#
# Cluster 4:
#   Animal Behavior and Welfare Studies, Veterinary Practice and Education Studies, Human-Animal Interaction Studies, Veterinary Oncology Research, Rabies epidemiology and control, Primate Behavior and Ecology, Ethnobotanical and Medicinal Plants Studies, Species Distribution and Climate Change, Plant-based Medicinal Research, Evolution and Paleontology Studies, Morphological variations and asymmetry
#
# Cluster 5:
#   Advanced Chemical Sensor Technologies, Insect Pheromone Research and Control, Spectroscopy and Laser Applications, Neurobiology and Insect Physiology Research, Studies on Chitinases and Chitosanases, Mosquito-borne diseases and control, Dengue and Mosquito Control Research, Parasite Biology and Host Interactions, Parasites and Host Interactions, Helminth infection and control
#
# Cluster 6:
#   Bamboo properties and applications, Wood Treatment and Properties, Environmental Impact and Sustainability, demographic modeling and climate adaptation, Social Acceptance of Renewable Energy, Skin Protection and Aging, melanin and skin pigmentation, Biochemical Analysis and Sensing Techniques, Regulation of Appetite and Obesity, Silk-based biomaterials and applications
#
# Cluster 7:
#   Advanced Causal Inference Techniques, Qualitative Comparative Analysis Research, Psychometric Methodologies and Testing, Cognitive and psychological constructs research, Advanced Statistical Modeling Techniques, Health Systems, Economic Evaluations, Quality of Life, Musculoskeletal Disorders and Rehabilitation, Medical History and Innovations, Health Sciences Research and Education
#
# Cluster 8:
#   Advanced Statistical Process Monitoring, Mineral Processing and Grinding, Big Data and Business Intelligence, Innovation, Sustainability, Human-Machine Systems, Legal, Health, Environmental and COVID-19 Challenges, Business and Economic Development, Labor Market and Education, Banking, Crisis Management, COVID-19 Impact, Advanced Technology in Applications
#
# Cluster 9:
#   Agriculture and Farm Safety, Traffic and Road Safety, Urban Transport and Accessibility, Water Resources and Sustainability, Regional resilience and development, Innovation and Knowledge Management, Safety Warnings and Signage, Older Adults Driving Studies, Injury Epidemiology and Prevention
#
# Cluster 10:
#   CO2 Sequestration and Geologic Interactions, Offshore Engineering and Technologies, Risk and Safety Analysis, Quality and Safety in Healthcare, Workplace Violence and Bullying, Workaholism, burnout, and well-being, Quality and Management Systems, Chemical Safety and Risk Management, Geothermal Energy Systems and Applications
#
# Cluster 11:
#   Advanced Energy Technologies and Civil Engineering Innovations, Structural mechanics and materials, Structural Response to Dynamic Loads, Probabilistic and Robust Engineering Design, Model Reduction and Neural Networks, Plant Growth Enhancement Techniques, Marine and coastal plant biology, Coral and Marine Ecosystems Studies
#
# Cluster 12:
#   Advanced Materials Characterization Techniques, Machine Learning in Materials Science, X-ray Spectroscopy and Fluorescence Analysis, Various Chemistry Research Topics, Computational Drug Discovery Methods, Pharmacogenetics and Drug Metabolism, Graph theory and applications, Liver Disease and Transplantation
#
# Cluster 13:
#   Advanced NMR Techniques and Applications, Solid-state spectroscopy and crystallography, Perovskite Materials and Applications, Technostress in Professional Settings, Work-Family Balance Challenges, Job Satisfaction and Organizational Behavior, Optical and Acousto-Optic Technologies, Electron Spin Resonance Studies
#
# Cluster 14:
#   Advanced Photocatalysis Techniques, ZnO doping and properties, Thin-Film Transistor Technologies, Nanomaterials for catalytic reactions, GaN-based semiconductor devices and materials, Caching and Content Delivery, Ammonia Synthesis and Nitrogen Reduction, Advanced oxidation water treatment
#
# Cluster 15:
#   Advanced Sensor and Energy Harvesting Materials, Tactile and Sensory Interactions, Gaze Tracking and Assistive Technology, Digital Accessibility for Disabilities, Conducting polymers and applications, Polydiacetylene-based materials and applications, Vacuum and Plasma Arcs, Fire effects on ecosystems
#
# Cluster 16:
#   Adventure Sports and Sensation Seeking, Robotic Locomotion and Control, Spaceflight effects on biology, Tardigrade Biology and Ecology, Magnetic and Electromagnetic Effects, Astro and Planetary Science, Isotope Analysis in Ecology, Hemispheric Asymmetry in Neuroscience
#
# Cluster 17:
#   Air Quality and Health Impacts, Vehicle emissions and performance, Thermoregulation and physiological responses, Occupational Health and Performance, Ergonomics and Musculoskeletal Disorders, Hydrogen Storage and Materials, Hybrid Renewable Energy Systems, Environmental Justice and Health Disparities
#
# Cluster 18:
#   Animal Virus Infections Studies, SARS-CoV-2 and COVID-19 Research, thermodynamics and calorimetric analyses, Evolution and Genetic Dynamics, Evolutionary Game Theory and Cooperation, Evolutionary Psychology and Human Behavior, COVID-19 epidemiological studies, COVID-19 Digital Contact Tracing
#
# Cluster 19:
#   Advanced Materials and Mechanics, Textile materials and evaluations, Micro and Nano Robotics, Diffusion and Search Dynamics, Bat Biology and Ecology Studies, Nonlinear Dynamics and Pattern Formation, Molecular spectroscopy and chirality
#
# Cluster 20:
#   Agricultural Economics and Policy, Sustainable Agricultural Systems Analysis, Efficiency Analysis Using DEA, Fiscal Policy and Economic Growth, Local Government Finance and Decentralization, Corporate Taxation and Avoidance, Energy, Environment, and Transportation Policies
#
# Cluster 21:
#   Analytical Methods in Pharmaceuticals, Protein purification and stability, Monoclonal and Polyclonal Antibodies Research, Biosimilars and Bioanalytical Methods, Safe Handling of Antineoplastic Drugs, Drug Solubulity and Delivery Systems, Crystallization and Solubility Studies
#
# Cluster 22:
#   Architecture and Cultural Influences, Building Energy and Comfort Optimization, Urban Heat Island Mitigation, Outdoor and Experiential Education, Educational Environments and Student Outcomes, Olfactory and Sensory Function Studies, Energy Efficiency and Management
#
# Cluster 23:
#   Atmospheric Ozone and Climate, Space exploration and regulation, Climate Change and Geoengineering, Environmental, Ecological, and Cultural Studies, Urban Agriculture and Sustainability, Rhetoric and Communication Studies, Laser Design and Applications
#
# Cluster 24:
#   Auditing, Earnings Management, Governance, Robotic Process Automation Applications, Electronic and Structural Properties of Oxides, Financial Markets and Investment Strategies, Risk and Portfolio Optimization, Fuzzy Systems and Optimization, Gambling Behavior and Treatments
#
# Cluster 25:
#   Child Nutrition and Water Access, Statistical Methods in Epidemiology, Emergency and Acute Care Studies, Nursing Roles and Practices, Healthcare Policy and Management, Pharmaceutical industry and healthcare, Public Health in Brazil
#
# Cluster 26:
#   Digitalization and Economic Development in Agriculture, Information Retrieval and Data Mining, Smart Agriculture and AI, Spectroscopy and Chemometric Analyses, Spectroscopy Techniques in Biomedical and Chemical Research, Soil Mechanics and Vehicle Dynamics, Remote Sensing in Agriculture
#
# Cluster 27:
#   Diverse Music Education Insights, Neuroscience and Music Perception, Music and Audio Processing, Music Therapy and Health, Gastrointestinal motility and disorders, Environmental Education and Sustainability, Tourism, Volunteerism, and Development
#
# Cluster 28:
#   AI in Service Interactions, Subtitles and Audiovisual Media, Second Language Acquisition and Learning, Foreign Language Teaching Methods, Organ and Tissue Transplantation Research, Service and Product Innovation
#
# Cluster 29:
#   Access Control and Trust, Topic Modeling, Personal Information Management and User Behavior, Biomedical Text Mining and Ontologies, Botanical Studies and Applications, Advanced Data and IoT Technologies
#
# Cluster 30:
#   Adversarial Robustness in Machine Learning, Psychopathy, Forensic Psychiatry, Sexual Offending, Traumatic Brain Injury Research, Neurology and Historical Studies, Mental Health and Psychiatry, Mental Health and Patient Involvement
#
# Cluster 31:
#   Agriculture Sustainability and Environmental Impact, Organic Food and Agriculture, Protein Hydrolysis and Bioactive Peptides, Biochemical effects in animals, Consumer Packaging Perceptions and Trends, Nanocomposite Films for Food Packaging
#
# Cluster 32:
#   Aluminum toxicity and tolerance in plants and animals, Heavy metals in environment, Radioactivity and Radon Measurements, Heavy Metals in Plants, Nigella sativa pharmacological applications, Food Science and Nutritional Studies
#
# Cluster 33:
#   Arctic and Russian Policy Studies, Indigenous Studies and Ecology, Geological Studies and Exploration, Methane Hydrates and Related Phenomena, Hydrocarbon exploration and reservoir analysis, Petroleum Processing and Analysis
#
# Cluster 34:
#   Assistive Technology in Communication and Mobility, Parkinson's Disease Mechanisms and Treatments, Phytochemistry and biological activities of Ficus species, Plant Gene Expression Analysis, Neurological diseases and metabolism, Disability Education and Employment
#
# Cluster 35:
#   Big Data Technologies and Applications, Methodology and Impact of Social Science Research, Imbalanced Data Classification Techniques, Vehicle License Plate Recognition, Financial Distress and Bankruptcy Prediction, Environmental Monitoring and Data Management
#
# Cluster 36:
#   Clay minerals and soil interactions, Soil Carbon and Nitrogen Dynamics, Soil and Water Nutrient Dynamics, Soil and Unsaturated Flow, Forest, Soil, and Plant Ecology in China, Coal and Its By-products
#
# Cluster 37:
#   Clostridium difficile and Clostridium perfringens research, Gut microbiota and health, Vitamin K Research Studies, Probiotics and Fermented Foods, Phytochemistry and Bioactivity Studies, Pediatric health and respiratory diseases
#
# Cluster 38:
#   Cloud Computing and Remote Desktop Technologies, Mechatronics Education and Applications, Mathematics Education and Teaching Techniques, Wittgensteinian philosophy and applications, Mathematics Education and Programs, Learning Styles and Cognitive Differences
#
# Cluster 39:
#   Collaboration in agile enterprises, Digital Transformation in Industry, Technology-Enhanced Education Studies, Online Learning and Analytics, Innovative Teaching and Learning Methods, Interdisciplinary Research and Collaboration
#
# Cluster 40:
#   Collagen: Extraction and Characterization, Proteins in Food Systems, Periodontal Regeneration and Treatments, Veterinary Equine Medical Research, Lower Extremity Biomechanics and Pathologies, Global Health and Epidemiology
#
# Cluster 41:
#   Community Development and Social Impact, Sustainability and Climate Change Governance, Public-Private Partnership Projects, Evaluation and Performance Assessment, Qualitative Research Methods and Ethics, Community Health and Development
#
# Cluster 42:
#   Creativity in Education and Neuroscience, Sustainable Design and Development, Digital Media and Visual Art, Fashion and Cultural Textiles, Islamic Studies and History, Optical Imaging and Spectroscopy Techniques
#
# Cluster 43:
#   Dental Education, Practice, Research, Diversity and Career in Medicine, Medical Education and Admissions, Human Resource and Talent Management, Human Resource Development and Performance Evaluation, Dental Health and Care Utilization
#
# Cluster 44:
#   Economic and Environmental Valuation, Quality Function Deployment in Product Design, Multi-Criteria Decision Making, Soil and Land Suitability Analysis, Rough Sets and Fuzzy Logic, Optimization and Mathematical Programming
#
# Cluster 45:
#   AI in cancer detection, Radiomics and Machine Learning in Medical Imaging, Immunotoxicology and immune responses, Breast Cancer Treatment Studies, Brain Tumor Detection and Classification
#
# Cluster 46:
#   Action Observation and Synchronization, Motor Control and Adaptation, Muscle activation and electromyography studies, Language and cultural evolution, Computability, Logic, AI Algorithms
#
# Cluster 47:
#   Adolescent Sexual and Reproductive Health, HIV/AIDS Research and Interventions, Sex work and related issues, HIV/AIDS Impact and Responses, LGBTQ Health, Identity, and Policy
#
# Cluster 48:
#   Advanced Antenna and Metasurface Technologies, Optical Coatings and Gratings, Photonic Crystals and Applications, Traumatic Ocular and Foreign Body Injuries, Stalking, Cyberstalking, and Harassment
#
# Cluster 49:
#   Advanced Computing and Algorithms, Scientific and Engineering Research Topics, Diabetic Foot Ulcer Assessment and Management, Pressure Ulcer Prevention and Management, Pharmacy and Medical Practices
#
# Cluster 50:
#   Advanced Electron Microscopy Techniques and Applications, Near-Field Optical Microscopy, Digital Holography and Microscopy, Electron and X-Ray Spectroscopy Techniques, High-pressure geophysics and materials
#
# Cluster 51:
#   Advanced Memory and Neural Computing, stochastic dynamics and bifurcation, Neural dynamics and brain function, Fractal and DNA sequence analysis, Blind Source Separation Techniques
#
# Cluster 52:
#   Aging, Elder Care, and Social Issues, Genetics, Aging, and Longevity in Model Organisms, GABA and Rice Research, Neuroscience and Neuropharmacology Research, Autophagy in Disease and Therapy
#
# Cluster 53:
#   American Constitutional Law and Politics, Legal and Constitutional Studies, History of Medicine and Tropical Health, Sex and Gender in Healthcare, Race, Genetics, and Society
#
# Cluster 54:
#   Antibiotic Resistance in Bacteria, Salmonella and Campylobacter epidemiology, Neutropenia and Cancer Infections, Surfactants and Colloidal Systems, Antibiotic Use and Resistance
#
# Cluster 55:
#   Aquatic Ecosystems and Biodiversity, Pleistocene-Era Hominins and Archaeology, Geology and Paleoclimatology Research, Maritime and Coastal Archaeology, Forensic and Genetic Research
#
# Cluster 56:
#   Art Therapy and Mental Health, Participatory Visual Research Methods, Autism Spectrum Disorder Research, Restless Legs Syndrome Research, Family and Disability Support Research
#
# Cluster 57:
#   Bone Tissue Engineering Materials, Thallium and Germanium Studies, Dental Implant Techniques and Outcomes, Facial Trauma and Fracture Management, Temporomandibular Joint Disorders
#
# Cluster 58:
#   Cannabis and Cannabinoid Research, Forensic Toxicology and Drug Analysis, Forensic Fingerprint Detection Methods, Mass Spectrometry Techniques and Applications, Ion-surface interactions and analysis
#
# Cluster 59:
#   Catalytic C–H Functionalization Methods, Fluorine in Organic Chemistry, Microbial metabolism and enzyme function, Per- and polyfluoroalkyl substances research, Pharmacological Effects and Assays
#
# Cluster 60:
#   Climate Change and Health Impacts, Medical and Agricultural Research Studies, Global Health Care Issues, Medical Device Sterilization and Disinfection, Healthcare and Environmental Waste Management
#
# Cluster 61:
#   Cognitive and developmental aspects of mathematical skills, Reading and Literacy Development, Neurobiology of Language and Bilingualism, Syntax, Semantics, Linguistic Variation, Natural Language Processing Techniques
#
# Cluster 62:
#   Culinary Culture and Tourism, Obesity, Physical Activity, Diet, Nutrition, Health and Food Behavior, Health and Wellbeing Research, Health disparities and outcomes
#
# Cluster 63:
#   Cultural Heritage Management and Preservation, Remote Sensing and Land Use, Remote-Sensing Image Classification, Environmental Changes in China, Urbanization and City Planning
#
# Cluster 64:
#   Digital Platforms and Economics, Merger and Competition Analysis, ICT Impact and Policies, Information Society and Technology Trends, ICT in Developing Communities
#
# Cluster 65:
#   Diverse Aspects of Tourism Research, Travel Writing and Literature, Nostalgia and Consumer Behavior, Korean Urban and Social Studies, Hospitality and Tourism Education
#
# Cluster 66:
#   Ear Surgery and Otitis Media, Hearing, Cochlea, Tinnitus, Genetics, Literature, Magical Realism, García Márquez, Noise Effects and Management, Vehicle Noise and Vibration Control
#
# Cluster 67:
#   Employee Welfare and Language Studies, Stuttering Research and Treatment, Parkinson's Disease and Spinal Disorders, Spanish Linguistics and Language Studies, Linguistic Studies and Language Acquisition
#
# Cluster 68:
#   Environmental Engineering and Cultural Studies, Recycling and utilization of industrial and municipal waste in materials production, Pigment Synthesis and Properties, nanoparticles nucleation surface interactions, Quasicrystal Structures and Properties
#
# Cluster 69:
#   Genetics and Physical Performance, Sports Performance and Training, Sports Dynamics and Biomechanics, Sport Psychology and Performance, Sports, Gender, and Society
#
# Cluster 70:
#   Human Health and Disease, Selenium in Biological Systems, Organoselenium and organotellurium chemistry, Sulfur-Based Synthesis Techniques, Surface Chemistry and Catalysis
#
# Cluster 71:
#   Marine Ecology and Invasive Species, Subterranean biodiversity and taxonomy, Planarian Biology and Electrostimulation, Slime Mold and Myxomycetes Research, Plant and Biological Electrophysiology Studies
#
# Cluster 72:
#   3D Surveying and Cultural Heritage, Satellite Image Processing and Photogrammetry, Remote Sensing and LiDAR Applications, Wood and Agarwood Research
#
# Cluster 73:
#   Adsorption and biosorption for pollutant removal, Environmental remediation with nanomaterials, Dye analysis and toxicity, Biopolymer Synthesis and Applications
#
# Cluster 74:
#   Advanced Aircraft Design and Technologies, Aviation Industry Analysis and Trends, Railway Systems and Energy Efficiency, Transportation Planning and Optimization
#
# Cluster 75:
#   Advanced Algebra and Logic, Algebraic structures and combinatorial models, Black Holes and Theoretical Physics, Earth Systems and Cosmic Evolution
#
# Cluster 76:
#   Advanced Computational Techniques and Applications, Geological Modeling and Analysis, Geotechnical and construction materials studies, Natural Fiber Reinforced Composites
#
# Cluster 77:
#   Advanced Electrical Measurement Techniques, Physics of Superconductivity and Magnetism, Quantum Information and Cryptography, Biofield Effects and Biophysics
#
# Cluster 78:
#   Advanced Frequency and Time Standards, Scientific Measurement and Uncertainty Evaluation, Sensor Technology and Measurement Systems, Advanced Statistical Methods and Models
#
# Cluster 79:
#   Advanced MEMS and NEMS Technologies, Force Microscopy Techniques and Applications, Electrostatics and Colloid Interactions, Polymer Surface Interaction Studies
#
# Cluster 80:
#   Advanced Mathematical Modeling in Engineering, Thermoelastic and Magnetoelastic Phenomena, Numerical methods in inverse problems, Polymer Foaming and Composites
#
# Cluster 81:
#   Advanced Polymer Synthesis and Characterization, biodegradable polymer synthesis and properties, Microplastics and Plastic Pollution, Marine Biology and Environmental Chemistry
#
# Cluster 82:
#   Advanced Radiotherapy Techniques, Radiation Therapy and Dosimetry, Optimal Experimental Design Methods, Statistical Methods in Clinical Trials
#
# Cluster 83:
#   Advanced battery technologies research, Electrocatalysts for Energy Conversion, Nanoporous metals and alloys, Electrochemical Analysis and Applications
#
# Cluster 84:
#   Aeolian processes and effects, Turfgrass Adaptation and Management, Plant Taxonomy and Phylogenetics, Genomics and Phylogenetic Studies
#
# Cluster 85:
#   Agriculture and Biological Studies, Phytochemical and Pharmacological Studies, Phytochemistry and Bioactive Compounds, Phytochemical Studies and Bioactivities
#
# Cluster 86:
#   Air Quality Monitoring and Forecasting, Atmospheric chemistry and aerosols, Plant responses to elevated CO2, Odor and Emission Control Technologies
#
# Cluster 87:
#   Algal biology and biofuel production, Bioeconomy and Sustainability Development, CRISPR and Genetic Engineering, Coffee research and impacts
#
# Cluster 88:
#   American Sports and Literature, Law in Society and Culture, Psychology of Moral and Emotional Judgment, Death Anxiety and Social Exclusion
#
# Cluster 89:
#   Amyloidosis: Diagnosis, Treatment, Outcomes, Parathyroid Disorders and Treatments, Magnesium in Health and Disease, Plant Micronutrient Interactions and Effects
#
# Cluster 90:
#   Analytic Number Theory Research, Coding theory and cryptography, graph theory and CDMA systems, Nanocluster Synthesis and Applications
#
# Cluster 91:
#   Animal Disease Management and Epidemiology, Viral gastroenteritis research and epidemiology, Fecal contamination and water quality, Vibrio bacteria research studies
#
# Cluster 92:
#   Animal health and immunology, Reproductive Physiology in Livestock, Gastrointestinal disorders and treatments, Cleft Lip and Palate Research
#
# Cluster 93:
#   Archaeological Research and Protection, Synthetic Aperture Radar (SAR) Applications and Techniques, Landslides and related hazards, Archaeology and Rock Art Studies
#
# Cluster 94:
#   Arctic and Antarctic ice dynamics, Winter Sports Injuries and Performance, Wave and Wind Energy Systems, Surface Modification and Superhydrophobicity
#
# Cluster 95:
#   Astronomical and nuclear sciences, Nuclear Issues and Defense, Radioactive contamination and transfer, Health and Conflict Studies
#
# Cluster 96:
#   Bioactive natural compounds, Sirtuins and Resveratrol in Medicine, Coconut Research and Applications, Fatty Acid Research and Health
#
# Cluster 97:
#   Biomarkers in Disease Mechanisms, Inflammasome and immune disorders, Pericarditis and Cardiac Tamponade, Plant and fungal interactions
#
# Cluster 98:
#   Botany, Ecology, and Taxonomy Studies, Nuts composition and effects, Tea Polyphenols and Effects, Edible Oils Quality and Analysis
#
# Cluster 99:
#   Bryophyte Studies and Records, Peatlands and Wetlands Ecology, Plant and Fungal Species Descriptions, Coastal and Marine Dynamics
#
# Cluster 100:
#   Building materials and conservation, Structural Analysis of Composite Materials, Conservation Techniques and Studies, Indoor Air Quality and Microbial Exposure
#
# Cluster 101:
#   Cancer Research and Treatment, Nanoparticle-Based Drug Delivery, Protein Interaction Studies and Fluorescence Analysis, Nanoplatforms for cancer theranostics
#
# Cluster 102:
#   Cellular and Composite Structures, Nonlocal and gradient elasticity in micro/nano structures, Erosion and Abrasive Machining, Rheology and Fluid Dynamics Studies
#
# Cluster 103:
#   Child Abuse and Related Trauma, Child and Adolescent Health, Child Abuse and Trauma, Child Welfare and Adoption
#
# Cluster 104:
#   Cinema and Media Studies, Video Analysis and Summarization, Shakespeare, Adaptation, and Literary Criticism, Diversity and Impact of Dance
#
# Cluster 105:
#   Cold Fusion and Nuclear Reactions, Magnetic confinement fusion research, Superconducting Materials and Applications, Fusion materials and technologies
#
# Cluster 106:
#   Complement system in diseases, Renal Diseases and Glomerulopathies, Plant-derived Lignans Synthesis and Bioactivity, Ginger and Zingiberaceae research
#
# Cluster 107:
#   Connexins and lens biology, Ion Channels and Receptors, Piperaceae Chemical and Biological Studies, Herbal Medicine Research Studies
#
# Cluster 108:
#   Conservation, Biodiversity, and Resource Management, Hydropower, Displacement, Environmental Impact, Water resources management and optimization, Water management and technologies
#
# Cluster 109:
#   Consumer Behavior in Brand Consumption and Identification, Media, Gender, and Advertising, Technology Adoption and User Behaviour, Digital Communication and Language
#
# Cluster 110:
#   Customer Service Quality and Loyalty, Emotional Labor in Professions, Mental Health via Writing, Memory Processes and Influences
#
# Cluster 111:
#   Cyclone Separators and Fluid Dynamics, ECG Monitoring and Analysis, EEG and Brain-Computer Interfaces, Emotion and Mood Recognition
#
# Cluster 112:
#   Decision-Making and Behavioral Economics, Philosophical Ethics and Theory, Hannah Arendt's Political Philosophy, Law, Economics, and Judicial Systems
#
# Cluster 113:
#   Dental Anxiety and Anesthesia Techniques, Occupational health in dentistry, Laser Applications in Dentistry and Medicine, Laser-Ablation Synthesis of Nanoparticles
#
# Cluster 114:
#   Dermatology and Skin Diseases, Psoriasis: Treatment and Pathogenesis, Neonatal skin health care, Obsessive-Compulsive Spectrum Disorders
#
# Cluster 115:
#   Disaster Management and Resilience, Flood Risk Assessment and Management, Karst Systems and Hydrogeology, Evacuation and Crowd Dynamics
#
# Cluster 116:
#   Diverse Approaches in Healthcare and Education Studies, Education and Learning Interventions, Diverse Topics in Contemporary Research, Innovation in Digital Healthcare Systems
#
# Cluster 117:
#   Drug-Induced Adverse Reactions, Pharmacovigilance and Adverse Drug Reactions, Pharmaceutical Economics and Policy, Medical Research and Practices
#
# Cluster 118:
#   Economic Growth and Development, Microfinance and Financial Inclusion, Social and Economic Development in India, FinTech, Crowdfunding, Digital Finance
#
# Cluster 119:
#   Electromagnetic Fields and Biological Effects, Ultrasound and Hyperthermia Applications, Ultrasound and Cavitation Phenomena, Ultrasound Imaging and Elastography
#
# Cluster 120:
#   Experimental Behavioral Economics Studies, Sports Analytics and Performance, Game Theory and Applications, Opinion Dynamics and Social Influence
#
# Cluster 121:
#   GNSS positioning and interference, Pulsars and Gravitational Waves Research, Geophysical and Geoelectrical Methods, Groundwater flow and contamination studies
#
# Cluster 122:
#   Hate Speech and Cyberbullying Detection, Social Media and Politics, Pharmaceutical Quality and Counterfeiting, Knowledge Management and Technology
#
# Cluster 123:
#   Impact of AI and Big Data on Business and Society, Legal and Policy Issues, Smart Cities and Technologies, Innovative Approaches in Technology and Social Development
#
# Cluster 124:
#   Musculoskeletal pain and rehabilitation, Veterinary Orthopedics and Neurology, Plant Toxicity and Pharmacological Properties, Occupational Therapy Practice and Research
#
# Cluster 125:
#   3D Printing in Biomedical Research, Hydrogels: synthesis, properties, applications, Animal testing and alternatives
#
# Cluster 126:
#   Academic Freedom and Politics, Communication in Education and Healthcare, Media Influence and Health
#
# Cluster 127:
#   Advanced Battery Materials and Technologies, Thermal Expansion and Ionic Conductivity, Optical properties and cooling technologies in crystalline materials
#
# Cluster 128:
#   Advanced Biosensing Techniques and Applications, Biosensors and Analytical Detection, SARS-CoV-2 detection and testing
#
# Cluster 129:
#   Advanced Differential Equations and Dynamical Systems, Nonlinear Waves and Solitons, Chaos-based Image/Signal Encryption
#
# Cluster 130:
#   Advanced Fiber Laser Technologies, Solid State Laser Technologies, Silicon Nanostructures and Photoluminescence
#
# Cluster 131:
#   Advanced Manufacturing and Logistics Optimization, Resource-Constrained Project Scheduling, Management and Optimization Techniques
#
# Cluster 132:
#   Advanced Neuroimaging Techniques and Applications, Functional Brain Connectivity Studies, Mental Health Research Topics
#
# Cluster 133:
#   Advanced Optical Imaging Technologies, Image and Video Quality Assessment, Multimedia Communication and Technology
#
# Cluster 134:
#   Advanced Optimization Algorithms Research, Optimization and Variational Analysis, Sparse and Compressive Sensing Techniques
#
# Cluster 135:
#   Advanced Queuing Theory Analysis, Simulation Techniques and Applications, Network Traffic and Congestion Control
#
# Cluster 136:
#   Advancements in Photolithography Techniques, Luminescence Properties of Advanced Materials, Radiation Detection and Scintillator Technologies
#
# Cluster 137:
#   Advances in Cucurbitaceae Research, Seed and Plant Biochemistry, Food composition and properties
#
# Cluster 138:
#   Aerodynamics and Fluid Dynamics Research, Wind and Air Flow Studies, Meteorological Phenomena and Simulations
#
# Cluster 139:
#   Agricultural safety and regulations, Effects and risks of endocrine disrupting chemicals, Polymer Science and PVC
#
# Cluster 140:
#   Agriculture, Land Use, Rural Development, Water Governance and Infrastructure, Mining and Resource Management
#
# Cluster 141:
#   Alzheimer's disease research and treatments, S100 Proteins and Annexins, Nuclear Receptors and Signaling
#
# Cluster 142:
#   Amoebic Infections and Treatments, Parasitic Infections and Diagnostics, Study of Mite Species
#
# Cluster 143:
#   Amphibian and Reptile Biology, Scarabaeidae Beetle Taxonomy and Biogeography, Plant and soil sciences
#
# Cluster 144:
#   Andrographolide Research and Applications, Inflammation biomarkers and pathways, Neuroinflammation and Neurodegeneration Mechanisms
#
# Cluster 145:
#   Anesthesia and Neurotoxicity Research, Intensive Care Unit Cognitive Disorders, Family and Patient Care in Intensive Care Units
#
# Cluster 146:
#   Animal Ecology and Behavior Studies, Plant and animal studies, Spider Taxonomy and Behavior Studies
#
# Cluster 147:
#   Animal and Plant Science Education, Insects and Parasite Interactions, Insect and Pesticide Research
#
# Cluster 148:
#   Antimicrobial Resistance in Staphylococcus, Microbial Metabolism and Applications, Plant Pathogenic Bacteria Studies
#
# Cluster 149:
#   Apelin-related biomedical research, Medicinal Plants and Bioactive Compounds, Phytochemistry and Biological Activities
#
# Cluster 150:
#   Aquatic Ecosystems and Phytoplankton Dynamics, Marine and coastal ecosystems, Diatoms and Algae Research
#
# Cluster 151:
#   Artistic and Creative Research, Digital Media and Philosophy, Digital Games and Media
#
# Cluster 152:
#   Asian Industrial and Economic Development, Indian Economic and Social Development, Energy and Environment Impacts
#
# Cluster 153:
#   Astrophysical Phenomena and Observations, Statistics Education and Methodologies, Mechanics and Biomechanics Studies
#
# Cluster 154:
#   Auction Theory and Applications, Game Theory and Voting Systems, Consumer Market Behavior and Pricing
#
# Cluster 155:
#   Automotive and Human Injury Biomechanics, Elasticity and Material Modeling, Connective tissue disorders research
#
# Cluster 156:
#   Avian ecology and behavior, Bird parasitology and diseases, Genetic diversity and population structure
#
# Cluster 157:
#   Bacillus and Francisella bacterial research, Poxvirus research and outbreaks, Herpesvirus Infections and Treatments
#
# Cluster 158:
#   Bacterial Genetics and Biotechnology, Bacteriophages and microbial interactions, Microbial infections and disease research
#
# Cluster 159:
#   Behavioral Health and Interventions, Physical Activity and Health, Health and Lifestyle Studies
#
# Cluster 160:
#   Bioactive Compounds and Antitumor Agents, Drug Transport and Resistance Mechanisms, Curcumin's Biomedical Applications
#
# Cluster 161:
#   Biochemical and biochemical processes, Lignin and Wood Chemistry, Enzyme-mediated dye degradation
#
# Cluster 162:
#   Bioenergy crop production and management, Forest Biomass Utilization and Management, Enzyme Production and Characterization
#
# Cluster 163:
#   Blockchain Technology Applications and Security, Sustainability and Innovation in Business, Impulse Buying and Technology Impacts
#
# Cluster 164:
#   Blood disorders and treatments, Neutrophil, Myeloperoxidase and Oxidative Mechanisms, Nitric Oxide and Endothelin Effects
#
# Cluster 165:
#   Boron Compounds in Chemistry, Rare-earth and actinide compounds, Boron and Carbon Nanomaterials Research
#
# Cluster 166:
#   Botany and Plant Ecology Studies, Yeasts and Rust Fungi Studies, Ecology and biodiversity studies
#
# Cluster 167:
#   Botulinum Toxin and Related Neurological Disorders, Myofascial pain diagnosis and treatment, Hereditary Neurological Disorders
#
# Cluster 168:
#   Brucella: diagnosis, epidemiology, treatment, Syphilis Diagnosis and Treatment, Reproductive tract infections research
#
# Cluster 169:
#   Business, Education, Mathematics Research, Diverse Applied Research Studies, Business, Innovation, and Economy
#
# Cluster 170:
#   CAR-T cell therapy research, Virus-based gene therapy research, Nanowire Synthesis and Applications
#
# Cluster 171:
#   CO2 Reduction Techniques and Catalysts, N-Heterocyclic Carbenes in Organic and Inorganic Chemistry, Ionic liquids properties and applications
#
# Cluster 172:
#   COVID-19 and Mental Health, Youth Substance Use and School Attendance, Parasitic Diseases Research and Treatment
#
# Cluster 173:
#   Canadian Policy and Governance, Insurance and Financial Risk Management, Financial Literacy, Pension, Retirement Analysis
#
# Cluster 174:
#   Cancer Genomics and Diagnostics, Mathematical Biology Tumor Growth, Genetic factors in colorectal cancer
#
# Cluster 175:
#   Carbohydrate Chemistry and Synthesis, Glycosylation and Glycoproteins Research, Galectins and Cancer Biology
#
# Cluster 176:
#   Carcinogens and Genotoxicity Assessment, Radiation Effects and Dosimetry, Environmental Chemistry and Analysis
#
# Cluster 177:
#   Cardiac Arrest and Resuscitation, Mechanical Circulatory Support Devices, Central Venous Catheters and Hemodialysis
#
# Cluster 178:
#   Cardiomyopathy and Myosin Studies, Williams Syndrome Research, Congenital heart defects research
#
# Cluster 179:
#   Career Development and Diversity, Mentoring and Academic Development, Doctoral Education Challenges and Solutions
#
# Cluster 180:
#   Characterization and Applications of Magnetic Nanoparticles, Magnetic properties of thin films, Magnetic Properties of Alloys
#
# Cluster 181:
#   Chemical Reaction Mechanisms, Energetic Materials and Combustion, Thermal and Kinetic Analysis
#
# Cluster 182:
#   Chemotherapy-induced organ toxicity mitigation, Lanthanide and Transition Metal Complexes, Synthesis and characterization of novel inorganic/organometallic compounds
#
# Cluster 183:
#   Childhood Cancer Survivors' Quality of Life, Family Support in Illness, Family Caregiving in Mental Illness
#
# Cluster 184:
#   China's Socioeconomic Reforms and Governance, Regulation and Compliance Studies, Land Rights and Reforms
#
# Cluster 185:
#   Chronic Myeloid Leukemia Treatments, Quinazolinone synthesis and applications, Kruppel-like factors research
#
# Cluster 186:
#   Climate Change Policy and Economics, Renewable energy and sustainable power systems, Climate Change and Sustainable Development
#
# Cluster 187:
#   Coastal Management and Development, Electrospun Nanofibers in Biomedical Applications, Wound Healing and Treatments
#
# Cluster 188:
#   Cognitive Functions and Memory, Dementia and Cognitive Impairment Research, Neurological Disorders and Treatments
#
# Cluster 189:
#   Communication and COVID-19 Impact, Data-Driven Disease Surveillance, Data Visualization and Analytics
#
# Cluster 190:
#   Computational Physics and Python Applications, Particle physics theoretical and experimental studies, Particle Accelerators and Free-Electron Lasers
#
# Cluster 191:
#   Concrete and Cement Materials Research, Smart Materials for Construction, Magnesium Oxide Properties and Applications
#
# Cluster 192:
#   Corporate Social Responsibility Reporting, Sustainable Finance and Green Bonds, Ethics in Business and Education
#
# Cluster 193:
#   Cosmology and Gravitation Theories, Statistical and numerical algorithms, Geophysics and Gravity Measurements
#
# Cluster 194:
#   Covalent Organic Framework Applications, Metal-Organic Frameworks: Synthesis and Applications, Membrane Separation and Gas Transport
#
# Cluster 195:
#   Craniofacial Disorders and Treatments, History of Medical Practice, History of Medicine Studies
#
# Cluster 196:
#   Cruise Tourism Development and Management, Maritime Transport Emissions and Efficiency, Maritime Ports and Logistics
#
# Cluster 197:
#   Crystal Structures and Properties, Organometallic Compounds Synthesis and Characterization, Mineralogy and Gemology Studies
#
# Cluster 198:
#   Crystal structures of chemical compounds, Nonlinear Optical Materials Research, Metal complexes synthesis and properties
#
# Cluster 199:
#   Cultural Differences and Values, Social and Intergroup Psychology, Organizational Leadership and Management Strategies
#
# Cluster 200:
#   Cultural Heritage Materials Analysis, Identification and Quantification in Food, Melamine detection and toxicity
#
# Cluster 201:
#   Demographic Trends and Gender Preferences, Reproductive Health and Technologies, Male Reproductive Health Studies
#
# Cluster 202:
#   Dermatological and Skeletal Disorders, Enzyme Structure and Function, Dupuytren's Contracture and Treatments
#
# Cluster 203:
#   Diamond and Carbon-based Materials Research, Fullerene Chemistry and Applications, Molecular Junctions and Nanostructures
#
# Cluster 204:
#   Dielectric materials and actuators, Synthesis and properties of polymers, Phosphorus compounds and reactions
#
# Cluster 205:
#   Digital Economy and Transformation, Innovation Policy and R&D, Economic and Technological Developments in Russia
#
# Cluster 206:
#   Digital Economy and Work Transformation, Sharing Economy and Platforms, Recreation, Leisure, Wilderness Management
#
# Cluster 207:
#   Direction-of-Arrival Estimation Techniques, Underwater Acoustics Research, Radar Systems and Signal Processing
#
# Cluster 208:
#   Diverse Educational Innovations Studies, Science Education and Perceptions, Service-Learning and Community Engagement
#
# Cluster 209:
#   EFL/ESL Teaching and Learning, Multilingual Education and Policy, Educational and Psychological Assessments
#
# Cluster 210:
#   Earthquake Detection and Analysis, Seismology and Earthquake Studies, Geoscience and Mining Technology
#
# Cluster 211:
#   Education Practices and Challenges, Teacher Professional Development and Motivation, Problem Solving Skills Development
#
# Cluster 212:
#   Education and Critical Thinking Development, Organizational Learning and Leadership, Ego Development and Educational Practices
#
# Cluster 213:
#   Educational Assessment and Improvement, Teacher Education and Leadership Studies, Survey Sampling and Estimation Techniques
#
# Cluster 214:
#   Environmental DNA in Biodiversity Studies, Paleopathology and ancient diseases, Forensic Entomology and Diptera Studies
#
# Cluster 215:
#   Environmental Philosophy and Ethics, Religion, Ecology, and Ethics, Marine and environmental studies
#
# Cluster 216:
#   European Union Policy and Governance, International Arbitration and Investment Law, Global Financial Regulation and Crises
#
# Cluster 217:
#   Facility Location and Emergency Management, Vehicle Routing Optimization Methods, Scheduling and Timetabling Solutions
#
# Cluster 218:
#   Fish Biology and Ecology Studies, Ichthyology and Marine Biology, Paleontology and Evolutionary Biology
#
# Cluster 219:
#   Fungal Biology and Applications, Plant Pathogens and Fungal Diseases, Powdery Mildew Fungal Diseases
#
# Cluster 220:
#   Genetic Neurodegenerative Diseases, Mitochondrial Function and Pathology, Glycogen Storage Diseases and Myoclonus
#
# Cluster 221:
#   Geochemistry and Geochronology of Asian Mineral Deposits, Metallurgical Processes and Thermodynamics, Grey System Theory Applications
#
# Cluster 222:
#   Global Financial Crisis and Policies, Global Trade and Competitiveness, World Trade Organization Law
#
# Cluster 223:
#   Graphene research and applications, Topological Materials and Phenomena, Quantum Computing Algorithms and Architecture
#
# Cluster 224:
#   Gun Ownership and Violence Research, Suicide and Self-Harm Studies, Restraint-Related Deaths
#
# Cluster 225:
#   Horticultural and Viticultural Research, Wine Industry and Tourism, Urbanism, Landscape, and Tourism Studies
#
# Cluster 226:
#   Inclusion and Disability in Education and Sport, Physical Education and Pedagogy, Motivation and Self-Concept in Sports
#
# Cluster 227:
#   Infant Health and Development, Neuroscience of respiration and sleep, Obstructive Sleep Apnea Research
#
# Cluster 228:
#   Innovation Diffusion and Forecasting, Sustainable Industrial Ecology, Sustainable Supply Chain Management
#
# Cluster 229:
#   Intermetallics and Advanced Alloy Properties, Microwave-Assisted Synthesis and Applications, MXene and MAX Phase Materials
#
# Cluster 230:
#   Membrane Separation Technologies, Solar-Powered Water Purification Methods, Membrane-based Ion Separation Techniques
#
# Cluster 231:
#   Natural product bioactivities and synthesis, Pharmacological Effects of Natural Compounds, Pharmacological Effects of Medicinal Plants
#
# Cluster 232:
#   Nephrotoxicity and Medicinal Plants, Plant Diversity and Evolution, Sesquiterpenes and Asteraceae Studies
#
# Cluster 233:
#   Neuropeptides and Animal Physiology, Receptor Mechanisms and Signaling, Renin-Angiotensin System Studies
#
# Cluster 234:
#   Paraquat toxicity studies and treatments, Pesticide and Herbicide Environmental Studies, Weed Control and Herbicide Applications
#
# Cluster 235:
#   Photochemistry and Electron Transfer Studies, Spectroscopy and Quantum Chemical Studies, Thermodynamic properties of mixtures
#
# Cluster 236:
#   Quantum Electrodynamics and Casimir Effect, Thermal Radiation and Cooling Technologies, Thermal properties of materials
#
# Cluster 237:
#   Random Matrices and Applications, Theoretical and Computational Physics, Solidification and crystal growth phenomena
#
# Cluster 238:
#   Vector-Borne Animal Diseases, Viral Infections and Vectors, Vector-borne infectious diseases
#
# Field Cooperations:
#
# 1. Medicine × Veterinary
#    Normalized Weight: 0.852
#
# 2. Immunology and Microbiology × Medicine
#    Normalized Weight: 0.765
#
# 3. Medicine × Nursing
#    Normalized Weight: 0.752
#
# 4. Health Professions × Medicine
#    Normalized Weight: 0.689
#
# 5. Earth and Planetary Sciences × Environmental Science
#    Normalized Weight: 0.681
#
# 6. Engineering × Materials Science
#    Normalized Weight: 0.634
#
# 7. Energy × Engineering
#    Normalized Weight: 0.582
#
# 8. Arts and Humanities × Social Sciences
#    Normalized Weight: 0.556
#
# 9. Dentistry × Medicine
#    Normalized Weight: 0.497
#
# 10. Biochemistry, Genetics and Molecular Biology × Medicine
#    Normalized Weight: 0.465
#
# Field Clusters:
#
# Cluster 1:
#   Agricultural and Biological Sciences, Biochemistry, Genetics and Molecular Biology, Pharmacology, Toxicology and Pharmaceutics, Medicine, Veterinary, Psychology, Nursing, Neuroscience, Immunology and Microbiology, Health Professions, Dentistry, Chemistry, Materials Science, Engineering, Energy, Chemical Engineering
#
# Summary Statistics:
# Total Topic Pairs: 17563
# Average Topic Normalized Weight: 0.141
# Average Papers per Topic Pair: 32.8
# Total Field Pairs: 272
# Average Field Normalized Weight: 0.097

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from io import BytesIO

def create_network_visualization(topic_metrics, min_edge_weight=0):
    """
    Create a network visualization of topic cooperations
    """
    # Initialize the graph
    G = nx.Graph()
    
    # Track unique fields and their topics
    fields = set()
    field_to_color = {}
    node_colors = {}
    edge_weights = {}
    
    # Process metrics to get fields and create edges
    for metric in topic_metrics[:25]:  # Take top 25 cooperations
        fields.add(metric['field1'])
        fields.add(metric['field2'])
        
        # Add edge with weight
        if metric['normalized_weight'] > min_edge_weight:
            G.add_edge(metric['topic1'], metric['topic2'], 
                      weight=metric['paper_count'])
            edge_weights[(metric['topic1'], metric['topic2'])] = metric['paper_count']
            
            # Track field information
            node_colors[metric['topic1']] = metric['field1']
            node_colors[metric['topic2']] = metric['field2']
    
    # Create color mapping for fields
    unique_fields = sorted(list(fields))
    colors = plt.cm.tab20(np.linspace(0, 1, len(unique_fields)))
    field_to_color = dict(zip(unique_fields, colors))
    
    # Create plot with extra space for legend
    plt.figure(figsize=(20, 23))  # Increase figure size to accommodate legend
    plt.subplots_adjust(top=0.75, bottom=0.2)  # Adjust spacing for legend at top or bottom
    
    # Compute layout with extra spacing
    pos = nx.spring_layout(G, k=0.6, iterations=50)
    
    # Draw edges first
    max_edge_weight = max(edge_weights.values())
    for (node1, node2), weight in edge_weights.items():
        width = 2 * weight / max_edge_weight
        nx.draw_networkx_edges(G, pos, 
                             edgelist=[(node1, node2)],
                             width=width,
                             alpha=0.4,
                             edge_color='gray')
    
    # Draw nodes
    for node in G.nodes():
        nx.draw_networkx_nodes(G, pos,
                             nodelist=[node],
                             node_color=[field_to_color[node_colors[node]]],
                             node_size=1000,
                             alpha=0.7)
    
    # Adjust labels to prevent overlap and limit to 30 chars
    label_pos = {node: (x, y + 0.05) for node, (x, y) in pos.items()}  # Offset label
    labels = {node: (node[:40] + '...') if len(node) > 40 else node for node in G.nodes()}
    nx.draw_networkx_labels(G, label_pos, labels, font_size=8, font_color='black')
    
    # Create legend elements
    legend_elements = [plt.Line2D([0], [0],
                                 marker='o',
                                 color='w',
                                 label=field,
                                 markerfacecolor=field_to_color[field],
                                 markersize=10,
                                 markeredgecolor='black')
                      for field in unique_fields]
    
    # Calculate number of columns for legend
    ncol = min(5, len(unique_fields))  # Maximum 5 columns
    
    # Add legend at the bottom to ensure it's not on the right
    plt.figlegend(handles=legend_elements,
                 title='Academic Fields',
                 title_fontsize=12,
                 fontsize=10,
                 loc='lower center',
                 # bbox_to_anchor=(0.5, -0.02),
                 ncol=ncol,
                 borderaxespad=0,
                 mode="expand")
    
    # Set title
    plt.title('Top 25 Cross-Field Topic Cooperations\n' +
             '(Edge width represents number of papers, Node colors represent academic fields)',
             pad=50, fontsize=14)
    
    # Remove axes
    plt.axis('off')
    
    # Convert to SVG
    img_stream = BytesIO()
    plt.savefig(img_stream, format='svg', bbox_inches='tight', dpi=300)
    plt.close()
    
    return img_stream.getvalue().decode()

def visualize_network(report):
    """
    Create network visualization from report
    """
    top_cooperations = report['topic_analysis']['top_cooperations']
    return create_network_visualization(top_cooperations)

# %%
    # Create visualization
    svg_content = visualize_network(report)
    
    # Save visualization as SVG artifact
    with open('topic_network.svg', 'w', encoding='utf-8') as f:
        f.write(svg_content)
